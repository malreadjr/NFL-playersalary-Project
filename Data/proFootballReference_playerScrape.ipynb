# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 2020 Player Information (Fantasy) - Pro Football Reference

# %%
url = 'https://www.pro-football-reference.com/years/2020/fantasy.htm'
df = pd.read_html(url)[0]
writepath = Path.cwd() / 'playerData2020.csv'
df['year'] = '2020'
df.to_csv (writepath, index = False, header=True)
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player                 Tm            FantPos
# 0                  1    Derrick Henry *                TEN                 RB
# 1                  2     Alvin Kamara *                NOR                 RB
# 2                  3       Dalvin Cook*                MIN                 RB
# 3                  4     Davante Adams*                GNB                 WR
# 4                  5      Travis Kelce*                KAN                 TE
#
#   Unnamed: 4_level_0 Games     Passing          ... Scoring      Fantasy  \
#                  Age     G  GS     Cmp Att Yds  ...     2PM  2PP  FantPt
# 0                 26    16  16       0   0   0  ...       1  NaN     314
# 1                 25    15  10       0   0   0  ...     NaN  NaN     295
# 2                 25    14  14       0   0   0  ...       3  NaN     294
# 3                 28    14  14       0   0   0  ...     NaN  NaN     243
# 4                 31    15  15       1   2   4  ...       1  NaN     208
#
#                                             year
#      PPR   DKPt   FDPt  VBD PosRank OvRank
# 0  333.1  341.1  323.6  184       1      1  2020
# 1  377.8  383.8  336.3  165       2      2  2020
# 2  337.8  346.8  315.8  164       3      3  2020
# 3  358.4  362.4  300.9  117       1      4  2020
# 4  312.8  316.8  260.3  117       1      5  2020
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 2019 Player Information (Fantasy) - Pro Football Reference

# %%
url = 'https://www.pro-football-reference.com/years/2019/fantasy.htm'
df = pd.read_html(url)[0]
writepath = Path.cwd() / 'playerData2019.csv'
df['year'] = '2019'
df.to_csv (writepath, index = False, header=True)
df.head()
# Out:
#   Unnamed: 0_level_0     Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk                 Player                 Tm
# 0                  1  Christian McCaffrey*+                CAR
# 1                  2        Lamar Jackson*+                BAL
# 2                  3        Derrick Henry *                TEN
# 3                  4            Aaron Jones                GNB
# 4                  5       Ezekiel Elliott*                DAL
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Games     Passing             ...  \
#              FantPos                Age     G  GS     Cmp  Att   Yds  ...
# 0                 RB                 23    16  16       0    2     0  ...
# 1                 QB                 22    15  15     265  401  3127  ...
# 2                 RB                 25    15  15       0    0     0  ...
# 3                 RB                 25    16  16       0    0     0  ...
# 4                 RB                 24    16  16       0    0     0  ...
#
#   Scoring      Fantasy                                           year
#       2PM  2PP  FantPt    PPR   DKPt   FDPt  VBD PosRank OvRank
# 0       1  NaN     355  471.2  477.2  413.2  215       1      1  2019
# 1     NaN  NaN     416  415.7  429.7  421.7  152       1      2  2019
# 2     NaN  NaN     277  294.6  303.6  285.6  136       2      3  2019
# 3     NaN  NaN     266  314.8  322.8  290.3  125       3      4  2019
# 4     NaN  NaN     258  311.7  319.7  284.7  117       4      5  2019
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 2018 Player Information (Fantasy) - Pro Football Reference

# %%
url = 'https://www.pro-football-reference.com/years/2018/fantasy.htm'
df = pd.read_html(url)[0]
writepath = Path.cwd() / 'playerData2018.csv'
df['year'] = '2018'
df.to_csv (writepath, index = False, header=True)
df.head()
# Out:
#   Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk               Player                 Tm
# 0                  1        Todd Gurley*+                LAR
# 1                  2      Saquon Barkley*                NYG
# 2                  3  Christian McCaffrey                CAR
# 3                  4       Alvin Kamara *                NOR
# 4                  5   Patrick Mahomes *+                KAN
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Games     Passing             ...  \
#              FantPos                Age     G  GS     Cmp  Att   Yds  ...
# 0                 RB                 24    14  14       0    0     0  ...
# 1                 RB                 21    16  16       0    0     0  ...
# 2                 RB                 22    16  16       1    1    50  ...
# 3                 RB                 23    15  13       0    0     0  ...
# 4                 QB                 23    16  16     383  580  5097  ...
#
#   Scoring      Fantasy                                           year
#       2PM  2PP  FantPt    PPR   DKPt   FDPt  VBD PosRank OvRank
# 0       3  NaN     313  372.1  379.1  342.6  178       1      1  2018
# 1       1  NaN     295  385.8  391.8  340.3  159       2      2  2018
# 2     NaN  NaN     279  385.5  392.5  332.0  143       3      3  2018
# 3       3  NaN     273  354.2  360.2  313.7  138       4      4  2018
# 4       1  NaN     417  417.1  437.1  429.1  134       1      5  2018
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 2017 Player Information (Fantasy) - Pro Football Reference

# %%
url = 'https://www.pro-football-reference.com/years/2017/fantasy.htm'
df = pd.read_html(url)[0]
writepath = Path.cwd() / 'playerData2017.csv'
df['year'] = '2017'
df.to_csv (writepath, index = False, header=True)
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player                 Tm            FantPos
# 0                  1      Todd Gurley*+                LAR                 RB
# 1                  2     Le'Veon Bell*+                PIT                 RB
# 2                  3       Kareem Hunt*                KAN                 RB
# 3                  4     Alvin Kamara *                NOR                 RB
# 4                  5      Melvin Gordon                LAC                 RB
#
#   Unnamed: 4_level_0 Games     Passing          ... Scoring      Fantasy  \
#                  Age     G  GS     Cmp Att Yds  ...     2PM  2PP  FantPt
# 0                 23    15  15       0   0   0  ...     NaN  NaN     319
# 1                 25    15  15       0   0   0  ...     NaN  NaN     257
# 2                 22    16  16       0   0   0  ...     NaN  NaN     242
# 3                 22    16   3       0   0   0  ...       1  NaN     239
# 4                 24    16  16       0   0   0  ...     NaN  NaN     230
#
#                                             year
#      PPR   DKPt   FDPt  VBD PosRank OvRank
# 0  383.3  391.3  351.3  192       1      1  2017
# 1  341.6  349.6  299.1  130       2      2  2017
# 2  295.2  302.2  268.7  115       3      3  2017
# 3  320.4  327.4  279.9  112       4      4  2017
# 4  288.1  294.1  259.1  103       5      5  2017
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 2016 Player Information (Fantasy) - Pro Football Reference

# %%
url = 'https://www.pro-football-reference.com/years/2016/fantasy.htm'
df = pd.read_html(url)[0]
writepath = Path.cwd() / 'playerData2016.csv'
df['year'] = '2016'
df.to_csv (writepath, index = False, header=True)
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player                 Tm            FantPos
# 0                  1    David Johnson*+                ARI                 RB
# 1                  2  Ezekiel Elliott*+                DAL                 RB
# 2                  3    Aaron Rodgers *                GNB                 QB
# 3                  4      LeSean McCoy*                BUF                 RB
# 4                  5      Le'Veon Bell*                PIT                 RB
#
#   Unnamed: 4_level_0 Games     Passing             ... Scoring      Fantasy  \
#                  Age     G  GS     Cmp  Att   Yds  ...     2PM  2PP  FantPt
# 0                 25    16  16       0    0     0  ...       1  NaN     328
# 1                 21    15  15       0    0     0  ...     NaN  NaN     293
# 2                 33    16  16     401  610  4428  ...       1    1     380
# 3                 28    15  15       0    0     0  ...       1  NaN     248
# 4                 24    12  12       0    1     0  ...       1  NaN     242
#
#                                             year
#      PPR   DKPt   FDPt  VBD PosRank OvRank
# 0  407.8  416.8  367.8  191       1      1  2016
# 1  325.4  332.4  309.4  156       2      2  2016
# 2  380.0  397.0  387.0  119       1      3  2016
# 3  298.3  304.3  273.3  111       3      4  2016
# 4  317.4  324.4  279.9  105       4      5  2016
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 2015 Player Information (Fantasy) - Pro Football Reference

# %%
url = 'https://www.pro-football-reference.com/years/2015/fantasy.htm'
df = pd.read_html(url)[0]
writepath = Path.cwd() / 'playerData2015.csv'
df['year'] = '2015'
df.to_csv (writepath, index = False, header=True)
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player                 Tm            FantPos
# 0                  1   Antonio Brown *+                PIT                 WR
# 1                  2  Devonta Freeman *                ATL                 RB
# 2                  3     Julio Jones *+                ATL                 WR
# 3                  4  Adrian Peterson*+                MIN                 RB
# 4                  5       Cam Newton*+                CAR                 QB
#
#   Unnamed: 4_level_0 Games     Passing             ... Scoring      Fantasy  \
#                  Age     G  GS     Cmp  Att   Yds  ...     2PM  2PP  FantPt
# 0                 27    16  16       0    0     0  ...       2  NaN     252
# 1                 23    15  13       0    0     0  ...     NaN  NaN     243
# 2                 26    16  16       0    0     0  ...     NaN  NaN     239
# 3                 30    16  16       0    0     0  ...     NaN  NaN     231
# 4                 26    16  16     296  495  3837  ...     NaN  NaN     389
#
#                                             year
#      PPR   DKPt   FDPt  VBD PosRank OvRank
# 0  388.2  393.2  320.2  125       1      1  2015
# 1  316.4  324.4  279.9  123       1      2  2015
# 2  375.1  379.1  307.1  111       2      3  2015
# 3  260.7  269.7  245.7  110       2      4  2015
# 4  389.1  409.1  399.1  105       1      5  2015
#
# [5 rows x 34 columns]
